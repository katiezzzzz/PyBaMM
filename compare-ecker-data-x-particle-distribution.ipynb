# %% [markdown]
# # Particle Distribution in X-direction

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import pybamm
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
os.chdir(pybamm.__path__[0]+'/..')
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/katiez/FUSE/pybamm/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
coin = {"particle shape":"negative coin"}
chemistry = pybamm.parameter_sets.Ecker2015

# %%
# load ecker data
voltage_data_1C = pd.read_csv("pybamm/input/discharge_data/Ecker_1C.csv", header=None).to_numpy()
voltage_data_5C = pd.read_csv("pybamm/input/discharge_data/Ecker_5C.csv", header=None).to_numpy()

# %% [markdown]
# ## Spherical

# %%
# choose DFN
model1 = pybamm.lithium_ion. DFN()
# choose SPMe
model2 = pybamm.lithium_ion. SPMe()

# %%
parameter_values0s = pybamm.ParameterValues(chemistry=chemistry)
parameter_values0s.update({"Current function [A]": "[input]"})
parameter_values0s.update({"Negative electrode diffusivity [m2.s-1]": "[function]graphite_diffusivity_Ecker2015"},
                        path="pybamm/input/parameters/lithium-ion/anodes/" + chemistry['anode'])

# %%
parameter_values1s = pybamm.ParameterValues(chemistry=chemistry)
parameter_values1s.update({"Current function [A]": "[input]"})
parameter_values1s.update({"Negative electrode diffusivity [m2.s-1]": "[function]graphite_diffusivity_Ecker2015_distribution"},
                        path="pybamm/input/parameters/lithium-ion/anodes/" + chemistry['anode'])
parameter_values1s.update({"Negative particle distribution in x": "[function]graphite_negative_particle_distribution_in_x_Ecker2015"},
                        path="pybamm/input/parameters/lithium-ion/anodes/" + chemistry['anode'])
#parameter_values1s.update({"Negative particle distribution in x": 2.0})
parameter_values1s
# Out:
# {'1 + dlnf/dlnc': 1.0,
#  'Ambient temperature [K]': 298.15,
#  'Bulk solvent concentration [mol.m-3]': 2636.0,
#  'Cation transference number': 0.26,
#  'Cell capacity [A.h]': 0.15625,
#  'Cell cooling surface area [m2]': 0.0172,
#  'Cell volume [m3]': 1.61e-06,
#  'Current function [A]': InputParameter(-0x34024b49b4eda613, Current function [A], children=[], domain=[], auxiliary_domains={}),
#  'EC diffusivity [m2.s-1]': 2e-18,
#  'EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'Edge heat transfer coefficient [W.m-2.K-1]': 0.3,
#  'Electrode height [m]': 0.10099999999999999,
#  'Electrode width [m]': 0.085,
#  'Electrolyte conductivity [S.m-1]': <function electrolyte_conductivity_Ecker2015 at 0x7f0bcab4aef0>,
#  'Electrolyte diffusivity [m2.s-1]': <function electrolyte_diffusivity_Ecker2015 at 0x7f0bcab4ad40>,
#  'Initial concentration in electrolyte [mol.m-3]': 1000.0,
#  'Initial concentration in negative electrode [mol.m-3]': 26120.05,
#  'Initial concentration in positive electrode [mol.m-3]': 12630.8,
#  'Initial inner SEI thickness [m]': 2.5e-09,
#  'Initial outer SEI thickness [m]': 2.5e-09,
#  'Initial temperature [K]': 298.15,
#  'Inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Inner SEI lithium interstitial diffusivity [m2.s-1]': 1.0000000000000001e-20,
#  'Inner SEI open-circuit potential [V]': 0.1,
#  'Inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Inner SEI reaction proportion': 0.5,
#  'Lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Lower voltage cut-off [V]': 2.5,
#  'Maximum concentration in negative electrode [mol.m-3]': 31920.0,
#  'Maximum concentration in positive electrode [mol.m-3]': 48580.0,
#  'Measured negative electrode OCP [V]': ('graphite_ocp_Ecker2015',
#                                          array([[0.00151515, 1.43251534],
#        [0.00606061, 0.86196319],
#        [0.01060606, 0.79141104],
#        [0.01666667, 0.6595092 ],
#        [0.02121212, 0.5797546 ],
#        [0.02272727, 0.52453988],
#        [0.03030303, 0.47546012],
#        [0.03939394, 0.41411043],
#        [0.04545455, 0.36809816],
#        [0.0530303 , 0.33128834],
#        [0.06666667, 0.28220859],
#        [0.07878788, 0.24846626],
#        [0.08939394, 0.22392638],
#        [0.10151515, 0.2208589 ],
#        [0.12727273, 0.21165644],
#        [0.14242424, 0.20245399],
#        [0.15909091, 0.1993865 ],
#        [0.17727273, 0.19325153],
#        [0.19393939, 0.18404908],
#        [0.21363636, 0.1809816 ],
#        [0.23333333, 0.17177914],
#        [0.25757576, 0.16564417],
#        [0.27878788, 0.16257669],
#        [0.3030303 , 0.15337423],
#        [0.32878788, 0.14110429],
#        [0.35151515, 0.13496933],
#        [0.37121212, 0.13190184],
#        [0.39242424, 0.12883436],
#        [0.56818182, 0.12576687],
#        [0.58787879, 0.12269939],
#        [0.60606061, 0.11656442],
#        [0.62727273, 0.10122699],
#        [0.65454545, 0.09509202],
#        [0.67424242, 0.09509202],
#        [0.69393939, 0.08895706],
#        [0.71818182, 0.08895706],
#        [0.73939394, 0.08588957],
#        [0.89090909, 0.08282209],
#        [0.95606061, 0.08272209],
#        [0.97727273, 0.0797546 ],
#        [1.        , 0.07055215]])),
#  'Measured negative electrode diffusivity [m2.s-1]': ('measured_graphite_diffusivity_Ecker2015',
#                                                       array([[4.29165947e-02, 2.53189836e-13],
#        [8.02533800e-02, 4.43829239e-14],
#        [1.20149569e-01, 3.19474263e-14],
#        [1.57961207e-01, 2.60779630e-14],
#        [1.95752274e-01, 2.25590858e-14],
#        [2.35765033e-01, 1.16865022e-14],
#        [2.71444120e-01, 1.23869273e-14],
#        [3.10028894e-01, 2.02919545e-14],
#        [3.48416526e-01, 3.26047164e-15],
#        [3.86670445e-01, 7.64015664e-16],
#        [4.26415779e-01, 8.41774737e-16],
#        [4.64186274e-01, 7.71709353e-16],
#        [5.01877913e-01, 8.83792155e-16],
#        [5.41211822e-01, 3.10917132e-15],
#        [5.76674911e-01, 6.06218467e-15],
#        [6.14803689e-01, 3.59593721e-14],
#        [6.54581594e-01, 2.03230938e-15],
#        [7.68139935e-01, 7.80266422e-16],
#        [8.08942973e-01, 7.72894292e-16],
#        [8.82303413e-01, 9.65829674e-16],
#        [9.22086460e-01, 9.56699959e-16],
#        [9.60750090e-01, 1.25457764e-15],
#        [9.97636023e-01, 1.39568471e-14]])),
#  'Measured positive electrode OCP [V]': ('nco_ocp_Ecker2015',
#                                          array([[1.06607849e-03, 4.58426321e+00],
#        [4.12737800e-02, 4.54243734e+00],
#        [6.53984009e-02, 4.52965007e+00],
#        [8.72254388e-02, 4.52332475e+00],
#        [1.11541525e-01, 4.49893236e+00],
#        [1.35474681e-01, 4.46985871e+00],
#        [1.59407836e-01, 4.42953849e+00],
#        [1.81745448e-01, 4.38920710e+00],
#        [2.05678604e-01, 4.34213893e+00],
#        [2.28016216e-01, 4.29955823e+00],
#        [2.51151600e-01, 4.25473380e+00],
#        [2.75084755e-01, 4.21666289e+00],
#        [2.98220139e-01, 4.17858640e+00],
#        [3.22153295e-01, 4.14726344e+00],
#        [3.45288679e-01, 4.11143626e+00],
#        [3.69221834e-01, 4.08236261e+00],
#        [3.93952762e-01, 4.05554386e+00],
#        [4.14694830e-01, 4.03094651e+00],
#        [4.40223529e-01, 4.00638266e+00],
#        [4.61763369e-01, 3.98404021e+00],
#        [4.86494297e-01, 3.96846803e+00],
#        [5.08831909e-01, 3.95287910e+00],
#        [5.32765064e-01, 3.94179997e+00],
#        [5.56698220e-01, 3.92397290e+00],
#        [5.78238060e-01, 3.91962497e+00],
#        [5.98182357e-01, 3.91301656e+00],
#        [6.48441983e-01, 3.91111887e+00],
#        [6.72375139e-01, 3.91128632e+00],
#        [6.97106067e-01, 3.89796345e+00],
#        [7.19443679e-01, 3.88237453e+00],
#        [7.43376834e-01, 3.86004882e+00],
#        [7.64916674e-01, 3.81746254e+00],
#        [7.88052058e-01, 3.78838331e+00],
#        [8.12782986e-01, 3.75931524e+00],
#        [8.35120598e-01, 3.73247975e+00],
#        [8.59053753e-01, 3.70790473e+00],
#        [8.82189137e-01, 3.68107481e+00],
#        [9.05324521e-01, 3.64974626e+00],
#        [9.30055448e-01, 3.61168094e+00],
#        [9.51595288e-01, 3.57809192e+00],
#        [9.68348497e-01, 3.55796529e+00],
#        [9.82708391e-01, 3.54232055e+00],
#        [9.99461600e-01, 3.51994462e+00]])),
#  'Measured positive electrode diffusivity [m2.s-1]': ('measured_nco_diffusivity_Ecker2015',
#                                                       array([[1.39432177e-01, 1.82565403e-13],
#        [2.00000000e-01, 3.32985856e-13],
#        [2.61829653e-01, 3.08012285e-13],
#        [3.22397476e-01, 2.63339203e-13],
#        [3.86750789e-01, 1.98119699e-13],
#        [4.46056782e-01, 1.41887887e-13],
#        [5.07886435e-01, 7.20118242e-14],
#        [5.68454259e-01, 2.85770870e-14],
#        [6.31545741e-01, 4.54160840e-15],
#        [6.93375394e-01, 5.47944475e-14],
#        [7.52681388e-01, 2.02968867e-13],
#        [8.15772871e-01, 1.58828651e-13],
#        [8.75078864e-01, 1.34460920e-13],
#        [9.40694006e-01, 2.05450533e-14],
#        [1.00000000e+00, 5.44629298e-15]])),
#  'Negative current collector surface heat transfer coefficient [W.m-2.K-1]': 0.0,
#  'Negative current collector thickness [m]': 1.4000000000000001e-05,
#  'Negative electrode Bruggeman coefficient (electrode)': 0.0,
#  'Negative electrode Bruggeman coefficient (electrolyte)': 1.6372789338386007,
#  'Negative electrode OCP [V]': <function graphite_ocp_Ecker2015_function at 0x7f0bcab4a560>,
#  'Negative electrode OCP entropic change [V.K-1]': 0.0,
#  'Negative electrode active material volume fraction': 0.372403,
#  'Negative electrode cation signed stoichiometry': -1.0,
#  'Negative electrode conductivity [S.m-1]': 14.0,
#  'Negative electrode diffusivity [m2.s-1]': <function graphite_diffusivity_Ecker2015_distribution at 0x7f0bcab615f0>,
#  'Negative electrode electrons in reaction': 1.0,
#  'Negative electrode exchange-current density [A.m-2]': <function graphite_electrolyte_exchange_current_density_Ecker2015 at 0x7f0bcab4a710>,
#  'Negative electrode porosity': 0.329,
#  'Negative electrode thickness [m]': 7.4e-05,
#  'Negative particle distribution in x': <function graphite_negative_particle_distribution_in_x_Ecker2015 at 0x7f0bcab617a0>,
#  'Negative particle radius [m]': 1.37e-05,
#  'Negative tab heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Number of cells connected in series to make a battery': 1.0,
#  'Number of electrodes connected in parallel to make a cell': 1.0,
#  'Outer SEI open-circuit potential [V]': 0.8,
#  'Outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Positive current collector surface heat transfer coefficient [W.m-2.K-1]': 0.0,
#  'Positive current collector thickness [m]': 2.5e-05,
#  'Positive electrode Bruggeman coefficient (electrode)': 0.0,
#  'Positive electrode Bruggeman coefficient (electrolyte)': 1.5442267190786427,
#  'Positive electrode OCP [V]': <function nco_ocp_Ecker2015_function at 0x7f0bcab4a9e0>,
#  'Positive electrode OCP entropic change [V.K-1]': 0.0,
#  'Positive electrode active material volume fraction': 0.40832,
#  'Positive electrode cation signed stoichiometry': -1.0,
#  'Positive electrode conductivity [S.m-1]': 68.1,
#  'Positive electrode diffusivity [m2.s-1]': <function nco_diffusivity_Ecker2015 at 0x7f0bcab4a8c0>,
#  'Positive electrode electrons in reaction': 1.0,
#  'Positive electrode exchange-current density [A.m-2]': <function nco_electrolyte_exchange_current_density_Ecker2015 at 0x7f0bcab4ac20>,
#  'Positive electrode porosity': 0.296,
#  'Positive electrode thickness [m]': 5.4000000000000005e-05,
#  'Positive particle distribution in x': 1.0,
#  'Positive particle radius [m]': 6.5e-06,
#  'Positive tab heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Ratio of inner and outer SEI exchange current densities': 1.0,
#  'Reference temperature [K]': 296.15,
#  'SEI kinetic rate constant [m.s-1]': 1e-12,
#  'SEI open-circuit potential [V]': 0.4,
#  'SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'SEI resistivity [Ohm.m]': 5000000.0,
#  'Separator Bruggeman coefficient (electrode)': 0.0,
#  'Separator Bruggeman coefficient (electrolyte)': 1.9804586773134945,
#  'Separator porosity': 0.508,
#  'Separator thickness [m]': 2e-05,
#  'Total heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Typical current [A]': 0.15652,
#  'Typical electrolyte concentration [mol.m-3]': 1000.0,
#  'Upper voltage cut-off [V]': 4.2}

# %%
var = pybamm.standard_spatial_vars
var_pts_s1 = {
    var.x_n: int(parameter_values0s.evaluate(model2.param.L_n / 1e-6)),
    var.x_s: int(parameter_values0s.evaluate(model2.param.L_s / 1e-6)),
    var.x_p: int(parameter_values0s.evaluate(model2.param.L_p / 1e-6)),
    var.r_n: int(parameter_values0s.evaluate(model2.param.R_n / 1e-7)),
    var.r_p: int(parameter_values0s.evaluate(model2.param.R_p / 1e-7)),
}

# %%
parameter_values0s.evaluate(model2.param.L_n / 1e-6)
# Out:
# 74.0

# %%
sim_S0 = pybamm.Simulation(model1, parameter_values=parameter_values0s, var_pts=var_pts_s1)
sim_S1 = pybamm.Simulation(model1, parameter_values=parameter_values1s, var_pts=var_pts_s1)

# %%
C_rates = [1, 5]  # C-rates to solve for
capacity = parameter_values0s["Cell capacity [A.h]"]
t_evals = [
    np.linspace(0, 3800, 100), 
    np.linspace(0, 720, 100)
] # times to return the solution at
solutions_S0 = [None] * len(C_rates)  # empty list that will hold solutions

# loop over C-rates
for i, C_rate in enumerate(C_rates):
    current = C_rate * capacity
    sim_S0.solve(t_eval=t_evals[i], solver=pybamm.CasadiSolver(mode="fast"),inputs={"Current function [A]": current})
    solutions_S0[i] = sim_S0.solution

# %%
C_rates = [1, 5]  # C-rates to solve for
capacity = parameter_values1s["Cell capacity [A.h]"]
t_evals = [
    np.linspace(0, 3800, 100), 
    np.linspace(0, 720, 100)
] # times to return the solution at
solutions_S1 = [None] * len(C_rates)  # empty list that will hold solutions

# loop over C-rates
for i, C_rate in enumerate(C_rates):
    current = C_rate * capacity
    sim_S1.solve(t_eval=t_evals[i], solver=pybamm.CasadiSolver(mode="safe"),inputs={"Current function [A]": current})
    solutions_S1[i] = sim_S1.solution
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: -3137239322143191279
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: 1508416904343257605
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: -6073426837821067803
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: -7917738057738746072
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: -7727589257693644644
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: 1232411734280144906
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     478         try:
# --> 479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
#
# KeyError: 7218045833761038249
#
# During handling of the above exception, another exception occurred:
#
# DomainError                               Traceback (most recent call last)
# <ipython-input-11-6d7ab9ebab54> in <module>
#      10 for i, C_rate in enumerate(C_rates):
#      11     current = C_rate * capacity
# ---> 12     sim_S1.solve(t_eval=t_evals[i], solver=pybamm.CasadiSolver(mode="safe"),inputs={"Current function [A]": current})
#      13     solutions_S1[i] = sim_S1.solution
#
# ~/FUSE/PyBaMM/pybamm/simulation.py in solve(self, t_eval, solver, external_variables, inputs, check_model)
#     336         """
#     337         # Setup
# --> 338         self.build(check_model=check_model)
#     339         if solver is None:
#     340             solver = self.solver
#
# ~/FUSE/PyBaMM/pybamm/simulation.py in build(self, check_model)
#     285             self._built_model = self.model
#     286         else:
# --> 287             self.set_parameters()
#     288             self._mesh = pybamm.Mesh(self._geometry, self._submesh_types, self._var_pts)
#     289             self._disc = pybamm.Discretisation(self._mesh, self._spatial_methods)
#
# ~/FUSE/PyBaMM/pybamm/simulation.py in set_parameters(self)
#     259         else:
#     260             self._model_with_set_params = self._parameter_values.process_model(
# --> 261                 self._unprocessed_model, inplace=False
#     262             )
#     263             self._parameter_values.process_geometry(self._geometry)
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_model(self, unprocessed_model, inplace)
#     356         for variable, equation in model.rhs.items():
#     357             pybamm.logger.debug("Processing parameters for {!r} (rhs)".format(variable))
# --> 358             model.rhs[variable] = self.process_symbol(equation)
#     359
#     360         for variable, equation in model.algebraic.items():
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     548         elif isinstance(symbol, pybamm.BinaryOperator):
#     549             # process children
# --> 550             new_left = self.process_symbol(symbol.left)
#     551             new_right = self.process_symbol(symbol.right)
#     552             # make new symbol, ensure domain remains the same
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     557         # Unary operators
#     558         elif isinstance(symbol, pybamm.UnaryOperator):
# --> 559             new_child = self.process_symbol(symbol.child)
#     560             new_symbol = symbol._unary_new_copy(new_child)
#     561             # ensure domain remains the same
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     557         # Unary operators
#     558         elif isinstance(symbol, pybamm.UnaryOperator):
# --> 559             new_child = self.process_symbol(symbol.child)
#     560             new_symbol = symbol._unary_new_copy(new_child)
#     561             # ensure domain remains the same
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     549             # process children
#     550             new_left = self.process_symbol(symbol.left)
# --> 551             new_right = self.process_symbol(symbol.right)
#     552             # make new symbol, ensure domain remains the same
#     553             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     549             # process children
#     550             new_left = self.process_symbol(symbol.left)
# --> 551             new_right = self.process_symbol(symbol.right)
#     552             # make new symbol, ensure domain remains the same
#     553             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     548         elif isinstance(symbol, pybamm.BinaryOperator):
#     549             # process children
# --> 550             new_left = self.process_symbol(symbol.left)
#     551             new_right = self.process_symbol(symbol.right)
#     552             # make new symbol, ensure domain remains the same
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     479             return self._processed_symbols[symbol.id]
#     480         except KeyError:
# --> 481             processed_symbol = self._process_symbol(symbol)
#     482
#     483             self._processed_symbols[symbol.id] = processed_symbol
#
# ~/FUSE/PyBaMM/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     552             # make new symbol, ensure domain remains the same
#     553             new_symbol = symbol._binary_new_copy(new_left, new_right)
# --> 554             new_symbol.domain = symbol.domain
#     555             return new_symbol
#     556
#
# ~/FUSE/PyBaMM/pybamm/expression_tree/symbol.py in domain(self, domain)
#     160         if domain == [] and self.auxiliary_domains != {}:
#     161             raise pybamm.DomainError(
# --> 162                 "Domain cannot be empty if auxiliary domains are not empty"
#     163             )
#     164         if domain in self.auxiliary_domains.values():
#
# DomainError: Domain cannot be empty if auxiliary domains are not empty

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C Spherical results
t_sol_S0 = solutions_S0[0]["Time [s]"].entries
t_sol_S1 = solutions_S1[0]["Time [s]"].entries
ax1.plot(t_sol_S0, solutions_S0[0]["Terminal voltage [V]"](t_sol_S0), label="single", alpha=0.8, color="skyblue")
ax1.plot(t_sol_S1, solutions_S1[0]["Terminal voltage [V]"](t_sol_S1), label="distribution", linestyle="--", color="green")
ax1.plot(voltage_data_1C[:,0], voltage_data_1C[:,1], "o", color='orange')
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("1C Spherical")
ax1.legend(loc="best")

# plot the 5C Spherical results
t_sol_S0 = solutions_S0[1]["Time [s]"].entries
t_sol_S1 = solutions_S1[1]["Time [s]"].entries
ax2.plot(t_sol_S0, solutions_S0[1]["Terminal voltage [V]"](t_sol_S0), label="single", alpha=0.8, color="skyblue")
ax2.plot(t_sol_S1, solutions_S1[1]["Terminal voltage [V]"](t_sol_S1), label="distribution", linestyle="--", color="green")
ax2.plot(voltage_data_5C[:,0], voltage_data_5C[:,1], "o", color='orange')
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Voltage [V]")
ax2.set_title("5C Spherical")
ax2.legend(loc="best")

plt.tight_layout()
plt.savefig('x distribution 1')
plt.show()
